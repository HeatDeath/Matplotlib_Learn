# %%
import numpy as np
import matplotlib
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置中文字体
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
# 生成测试数据
'''
numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None)
在指定的间隔内返回均匀间隔（num）的数字。

返回数字间隔均匀的样本，以间隔[start，stop]计算。

间隔的终点可以可选地被排除。
'''
x = np.linspace(-np.pi, np.pi, 256, endpoint=True)
y_cos, y_sin = np.cos(x), np.sin(x)

# %%
# 生成画布，并设定标题
# 创建一个 8 * 6 点（point）的图，并设置分辨率为 80
plt.figure(figsize=(8, 6), dpi=80)

# fontproperties 字体属性
plt.title("可视化标题")

# 是否显示格子
plt.grid(True)

# %%
# 设置 x 轴标签
plt.xlabel("X轴")

# 设置 x 轴刻度范围
plt.xlim(-4.0, 4.0)

# 设置 x 轴刻度值
# 第三个参数为 刻度值 的数量
plt.xticks(np.linspace(-4, 4, 9, endpoint=True))

# 设置Y轴
plt.ylabel("Y轴")
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 9, endpoint=True))
# Out:
# ([<matplotlib.axis.YTick at 0x2bd2065ecc0>,
#   <matplotlib.axis.YTick at 0x2bd203085f8>,
#   <matplotlib.axis.YTick at 0x2bd2065f518>,
#   <matplotlib.axis.YTick at 0x2bd201d10b8>,
#   <matplotlib.axis.YTick at 0x2bd2065f240>,
#   <matplotlib.axis.YTick at 0x2bd1f2e6198>,
#   <matplotlib.axis.YTick at 0x2bd202d07f0>,
#   <matplotlib.axis.YTick at 0x2bd203a3278>,
#   <matplotlib.axis.YTick at 0x2bd203a3a90>],
#  <a list of 9 Text yticklabel objects>)

# %%
# 画两条曲线
# 第三个参数为 颜色线型
plt.plot(x, y_cos, "b--", linewidth=2.0, label="cos图像")
plt.plot(x, y_sin, "g-", linewidth=2.0, label="sin图像")

# %%
# 设置图例位置,loc可以为[upper, lower, left, right, center]
plt.legend(loc="upper left", shadow=True)

# 图形显示
plt.show()
